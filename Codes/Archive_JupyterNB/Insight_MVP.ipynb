# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-0.1"><span class="toc-item-num">0.1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Metric-Design" data-toc-modified-id="Metric-Design-0.2"><span class="toc-item-num">0.2&nbsp;&nbsp;</span>Metric Design</a></span><ul class="toc-item"><li><span><a href="#It-is-regression-problem" data-toc-modified-id="It-is-regression-problem-0.2.1"><span class="toc-item-num">0.2.1&nbsp;&nbsp;</span>It is regression problem</a></span></li></ul></li><li><span><a href="#Data-Files" data-toc-modified-id="Data-Files-0.3"><span class="toc-item-num">0.3&nbsp;&nbsp;</span>Data Files</a></span></li><li><span><a href="#Merge-Geographical-Data-with-Zipcodes" data-toc-modified-id="Merge-Geographical-Data-with-Zipcodes-0.4"><span class="toc-item-num">0.4&nbsp;&nbsp;</span>Merge Geographical Data with Zipcodes</a></span></li></ul></li><li><span><a href="#Preprocessing-Step" data-toc-modified-id="Preprocessing-Step-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preprocessing Step</a></span><ul class="toc-item"><li><span><a href="#Hot-encoded-Features" data-toc-modified-id="Hot-encoded-Features-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Hot encoded Features</a></span></li><li><span><a href="#Augmentation" data-toc-modified-id="Augmentation-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Augmentation</a></span></li><li><span><a href="#Train_Test-Split" data-toc-modified-id="Train_Test-Split-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Train_Test Split</a></span></li></ul></li><li><span><a href="#Plotting-Scheme" data-toc-modified-id="Plotting-Scheme-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plotting Scheme</a></span><ul class="toc-item"><li><span><a href="#Hyper-Parameter-Tunning" data-toc-modified-id="Hyper-Parameter-Tunning-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Hyper Parameter Tunning</a></span></li><li><span><a href="#Reduce-number-of-features,-better-keyword-Handling" data-toc-modified-id="Reduce-number-of-features,-better-keyword-Handling-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Reduce number of features, better keyword Handling</a></span></li><li><span><a href="#More-data-processing" data-toc-modified-id="More-data-processing-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>More data processing</a></span></li></ul></li><li><span><a href="#NLTK-USE:-Data-Cleaning-and-text-preprocessing" data-toc-modified-id="NLTK-USE:-Data-Cleaning-and-text-preprocessing-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>NLTK USE: Data Cleaning and text preprocessing</a></span><ul class="toc-item"><li><span><a href="#Tokenizing,-padding-each-keyword-into-similar-size-arrow" data-toc-modified-id="Tokenizing,-padding-each-keyword-into-similar-size-arrow-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Tokenizing, padding each keyword into similar size arrow</a></span></li><li><span><a href="#Creating-Input,-Out-Features" data-toc-modified-id="Creating-Input,-Out-Features-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Creating Input, Out Features</a></span></li></ul></li><li><span><a href="#Word2Vec-Google-TL" data-toc-modified-id="Word2Vec-Google-TL-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Word2Vec Google TL</a></span></li></ul></div>

# %% [markdown]
# ## Libraries ##

# %%
import os
import pandas as pd
import time
import math
import copy
import numpy as np
from numpy import linalg as LA
import sys
import argparse
import requests
import time 
import matplotlib.pyplot as plt
import matplotlib
import string
import numpy as np
import pandas as pd
from pickle import load
import operator
from sklearn.utils import shuffle


## Classifier ## 
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor

## Commonly Used Modules ##
import time 
import matplotlib.pyplot as plt
import matplotlib
import string
import numpy as np
import pandas as pd
from pickle import load
import operator

## sklearn modules, classical ML ## 
import sklearn
from sklearn.model_selection import ShuffleSplit, train_test_split
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import RandomForestClassifier
from sklearn.utils.extmath import density
from sklearn import metrics
from sklearn import model_selection
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.base import BaseEstimator,TransformerMixin
from sklearn.preprocessing import Normalizer


## Natural Language tool kit dealing with text mining ## 
from nltk.corpus import stopwords as sw
from nltk.corpus import wordnet as wn
from nltk import wordpunct_tokenize
from nltk.stem import WordNetLemmatizer
from nltk import sent_tokenize
from nltk import pos_tag



## Deep learning Modules ##
from keras.preprocessing.text import Tokenizer
from keras.layers import Input, Dense
from keras.models import Model
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.layers import LSTM
from keras.layers import GlobalMaxPool1D
from keras.layers import Dropout
from keras.preprocessing.sequence import pad_sequences
from keras.callbacks import ModelCheckpoint


## Metric Modules ## 
from sklearn.metrics import hamming_loss
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score, fbeta_score  
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from functools import partial
from collections import defaultdict

# %% [markdown]
# ## Metric Design ##
# ### It is regression problem ###

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from functools import partial
from collections import defaultdict 


def mean_absolute_percentage_error(y_true, y_pred):
    N=len(y_true)
    L=N
    for i in range(N):
        if y_true[i]!=0: 
            Sum=Sum+abs(y_true[i]-y_pred[i])/y_true[i]
        else:
            L=L-1
    return Sum/L
    
METRICS = {
    "r2_score":r2_score,
    "MAPE": mean_absolute_percentage_error,
    "mean_squared_error": mean_squared_error,
}

#records = defaultdict(dict)
#list_classes=[]
#list_classes.append("toxic")
#for metric_name,metric in METRICS.items():
#    for j in range(len(list_classes)):
#        records[metric_name][list_classes[j]]=metric(y_test,tfidfPredicted) ## Measuring the metrics ##

# %% [markdown]
# ## Data Files ##

# %%
File='/Users/mohammadmehdiezzatabadipour/Dropbox/Insight/DATA/'
pd.set_option("display.max_rows", 100, "display.max_columns", 100)

# %% [markdown]
# ## Merge Geographical Data with Zipcodes ##

# %%
Table1=pd.read_csv(File+'Zipcode_Summary_Account_keyword_NumberFormat.csv')
#Table1=pd.read_csv(File+'Zipcode_Summary_Account.csv')
Table2=pd.read_csv(File+'Geo_Latitide_Longitude.csv')
Table=Table1.merge(Table2, left_on='ZipCode', right_on='ZipCode')
Table['Revenue/Cost']=Table['$ Received']/Table['$ Ad Cost']
Table = Table[Table['Clicks']>0]
Table=Table.fillna(0)
TableCopy=copy.deepcopy(Table)

# %%
#TableCopy

# %%
Aggregation={'State':'first','AreaCode':'first','City':'last','Impression Share (IS)':'mean','Clicks':'sum','# Call Conversions':'sum',\
 '# Invoiced':'sum','# of Payments':'sum','$ Ad Cost':'sum','$ Invoiced':'sum','$ Received':'sum', 'Latitude':'mean','Longitude':'mean'}

GROUPBY=['ZipCode','Keyword']


def CustAgg(TableCopy,AggregateDict,GROUPBY):    
    TableGroup=TableCopy.groupby(GROUPBY).agg(Aggregation)
    TableGroup=TableGroup.reset_index()
    TableGroup['CPC']=TableGroup['$ Ad Cost']/TableGroup['Clicks']
    TableGroup['$ Revenue / $ Ad Cost']=TableGroup['$ Received']/TableGroup['$ Ad Cost']
    TableGroup['$ Paid / $ Invoiced']=TableGroup['$ Received']/TableGroup['$ Invoiced']
    TableGroup['CR']=TableGroup['# Call Conversions']/TableGroup['Clicks']
    TableGroup.replace('', np.nan, inplace=True)
    TableGroup.fillna(0,inplace=True)
    return TableGroup
    #    TableGroup.to_csv(File+'Area_Keyword.csv')
    
df=CustAgg(TableCopy,Aggregation,GROUPBY)
df['AreaCode']=list(df['AreaCode'].astype(str))

# %%
#df.columns
df
# Out:
#       ZipCode                          Keyword  State AreaCode       City  \
# 0       75001    american structural engineers  Texas      469    Addison
# 1       75001           foundation engineering  Texas      469    Addison
# 2       75001         home structural engineer  Texas      469    Addison
# 3       75001  residential foundation engineer  Texas      469    Addison
# 4       75001  residential structural engineer  Texas      469    Addison
# ...       ...                              ...    ...      ...        ...
# 1443    78801      structural engineer near me  Texas      830     Uvalde
# 1444    78932       structural home inspection  Texas      979    Carmine
# 1445    78932             windstorm inspection  Texas      979    Carmine
# 1446    78947              structural engineer  Texas      979  Lexington
# 1447    78950              structural engineer  Texas      979    New-Ulm
#
#       Impression Share (IS)  Clicks  # Call Conversions  # Invoiced  \
# ...

# %% [markdown]
# # Preprocessing Step #
# ## Hot encoded Features ##

# %%
Hot_Encoded=['Keyword','AreaCode']
Target=['CR']
Extra_Predictant=['Clicks','CPC']
dummy=df[Hot_Encoded]
features_final = pd.get_dummies(dummy)
features_final[Extra_Predictant]=df[Extra_Predictant]
target=df[Target]

# %%
Keyword=df['Keyword']
Keyword=list(set(Keyword))

# %%
Dict={}
for key in Keyword:
    Dict[key]={'Clicks':sum(df[df['Keyword']==key].Clicks),'$ Ad Cost':sum(df[df['Keyword']==key]['$ Ad Cost']),\
               '#Calls':1.0*sum(df[df['Keyword']==key]['# Call Conversions']),'CR:Calls per Click':1.0*sum(df[df['Keyword']==key]['# Call Conversions'])/sum(df[df['Keyword']==key].Clicks),'# Invoices':sum(df[df['Keyword']==key]['# Invoiced']),
               'Ad Revenue':sum(df[df['Keyword']==key]['$ Received']),\
               'Revenue/Cost':sum(df[df['Keyword']==key]['$ Received'])/sum(df[df['Keyword']==key]['$ Ad Cost'])}

# %%
pd.DataFrame.from_dict(Dict)
# Out:
#                     foundation engineer inspection  structural firm  \
# Clicks                                   37.000000         4.000000
# $ Ad Cost                               443.970000        39.190000
# #Calls                                    0.000000         0.000000
# CR:Calls per Click                        0.000000         0.000000
# # Invoices                               16.000000         4.000000
# Ad Revenue                             1750.000000      1350.000000
# Revenue/Cost                              3.941708        34.447563
#
#                     residential structural engineer near me  \
# Clicks                                            23.000000
# $ Ad Cost                                        279.570000
# #Calls                                             6.250000
# CR:Calls per Click                                 0.271739
# # Invoices                                        25.000000
# ...

# %%
Keyword_Performance=pd.DataFrame.transpose(pd.DataFrame.from_dict(Dict))

# %%
SS=Keyword_Performance.sort_values(by=['Revenue/Cost'],ascending=False)
SS=SS[SS['CR:Calls per Click']!=0]
SS
# Out:
#                                                     Clicks  $ Ad Cost  #Calls  \
# structural engineer inspection near me                 4.0      44.18    1.00
# residential structural inspection                      8.0      93.60    2.00
# best structural engineer                               7.0      62.01    0.33
# resident engineer                                     17.0     163.66    2.00
# structural home inspection                             9.0     110.14    1.00
# local structural engineer                              2.0      24.77    3.00
# structural engineering companies                      25.0     214.16    2.00
# home inspection engineers                             19.0     219.71    5.00
# structural engineer near me                          114.0    1164.32   13.91
# structural engineer inspection                        74.0     776.05    6.00
# structural engineer inspection cost                   12.0     127.03    1.00
# ...

# %% [markdown]
# ## Augmentation ##

# %%
repeat=df[df['# Call Conversions']!=0]
final_df=copy.deepcopy(df)
for i in range(8):
    final_df=pd.concat([final_df,repeat])
    
final_df = shuffle(final_df)

# %%
ZZ=final_df[final_df.CR!=0]
ZZ.shape
# Out:
# (1971, 19)

# %%
Hot_Encoded=['Keyword','AreaCode']
Target=['CR']
Extra_Predictant=['Clicks','CPC']
dummy=final_df[Hot_Encoded]
features_final = pd.get_dummies(dummy)
features_final[Extra_Predictant]=final_df[Extra_Predictant]
target=final_df[Target]

# %%
SZ=final_df[['Keyword','City','AreaCode','ZipCode','CPC','Clicks','# Call Conversions','$ Ad Cost','$ Received']]
SZ[:10]
# Out:
#                                 Keyword         City AreaCode  ZipCode  \
# 273                     home inspection       Dallas      469    75230
# 617   residential construction engineer         Waco      817    76704
# 392                 structural engineer    Arlington      817    76013
# 688                 structural engineer      Houston      832    77027
# 809      structural engineer inspection      Houston      832    77095
# 113               home inspection class     Mckinney      469    75070
# 1358                structural engineer       Luling      830    78648
# 1                foundation engineering      Addison      469    75001
# 1310    residential structural engineer  San-Antonio      210    78258
# 211               structural inspection      Red-Oak      469    75154
#
#             CPC  Clicks  # Call Conversions  $ Ad Cost  $ Received
# 273   15.220000     1.0                 0.0      15.22         0.0
# ...

# %%
final_df.columns
# Out:
# Index(['ZipCode', 'Keyword', 'State', 'AreaCode', 'City',
#        'Impression Share (IS)', 'Clicks', '# Call Conversions', '# Invoiced',
#        '# of Payments', '$ Ad Cost', '$ Invoiced', '$ Received', 'Latitude',
#        'Longitude', 'CPC', '$ Revenue / $ Ad Cost', '$ Paid / $ Invoiced',
#        'CR'],
#       dtype='object')

# %% [markdown]
# ## Train_Test Split ##

# %%
# Import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features_final, 
                                                    target, 
                                                    test_size = 0.1, 
                                                    random_state = 1)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 2880 samples.
# Testing set has 320 samples.

# %% [markdown]
# # Plotting Scheme #

# %%
from matplotlib import pyplot as plt
import math
import matplotlib.style
import matplotlib as mpl
mpl.style.use('default')


def plot_square(Yo,Yp, Ymin, Ymax, Param='CR', Title='Asset_id'):

    plt.clf()
    q0 = np.arange(Ymin, Ymax, 0.1)
    q = q0
## Error Angles ## 
    coefs=[math.tan(math.radians(45*(0.95))),math.tan(math.radians(45*(1.05))),math.tan(math.radians(0.85*45)),math.tan(math.radians(1.15*45)),math.tan(math.radians(0.7*45)),math.tan(math.radians(1.3*45))]

    q10=coefs[0]*q0
    q11=coefs[1]*q0
    q20=coefs[2]*q0
    q21=coefs[3]*q0
    q30=coefs[4]*q0
    q31=coefs[5]*q0



    fig, ax = plt.subplots(figsize=(8,8),frameon=True)
    ax.set_facecolor((1, 1, 1))
    a1=plt.scatter(Yo,Yp,c='k')#, label="Monthly average of Daily prediction")
    ax.legend()


    a3,=plt.plot(q0,q,label="Reference line",c='k')
    a4,=plt.plot(q0,q10,label="$\pm 5%$ error",ls='--',c='b')
    plt.plot(q0,q11,ls='--',c='b')
    a5,=plt.plot(q0,q20,label="$\pm 15%$ error",ls='--',c='r')
    plt.plot(q0,q21,ls='--',c='r')
    a6,=plt.plot(q0,q30,label="$\pm 30%$ error",ls='--',c='g')
    plt.plot(q0,q31,ls='--',c='g')

#    plt.xlabel(Param+"$_{Observed}$ ")
#    plt.ylabel(Param+"$_{Forcasted}$")
    plt.xlabel("$Observed$ ",fontsize=15)
    plt.ylabel("$Predicted$",fontsize=15)

    plt.xlim(Ymin, Ymax)
    plt.ylim(Ymin, Ymax)
#plt.grid(False)
    plt.title(Title,fontsize=15)
    plt.xticks(fontsize=15 )
    plt.yticks(fontsize=15 )
    ax.spines['bottom'].set_color('0.5')
    ax.spines['top'].set_color('0.5') 
    ax.spines['right'].set_color('0.5')
    ax.spines['left'].set_color('0.5')
    plt.rc('lines', lw=1, color='b')
    legends=["Reference line","$\pm 5\%$ error","$\pm 15\%$ error","$\pm 30\%$ error"]
    plt.legend([a3,a4,a5,a6],legends,fontsize=15)
    return plt

# %% [markdown]
# ## Hyper Parameter Tunning ##

# %%
## Decision Tree ## 
Max_Depths=[1,10,13,14,15,20,30,40,50,100]
CLF_A=[DecisionTreeRegressor(max_depth=Max_Depths[i],min_samples_leaf=1) for i in range(len(Max_Depths))]
MSE=[]
r2Score=[]
results={}
for clf in CLF_A:
    clf_name = clf.__class__.__name__
    
    # Train #
    clf.fit(X_train, y_train)

    # Predict #
    results[clf_name] = clf.predict(X_test)
    MSE.append(mean_squared_error(y_test,results[clf_name]))
    r2Score.append(r2_score(y_test,results[clf_name]))
    
    plt=plot_square(y_test, results[clf_name],0,1,Title=clf_name)    
    
#    plt.figure()
#    plt.scatter(y_test, results[clf_name], s=20, edgecolor="black",c="darkorange", label="data")
#    plt.xlabel("Observed CR")
#    plt.ylabel("Predicted CR")
#    plt.title(clf_name+" Regression")
#    plt.legend()
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
MSE
# Out:
# [0.24117818659285514,
#  0.12696383313494902,
#  0.09734779804404681,
#  0.09212587642418388,
#  0.08176881856903054,
#  0.06585398851392174,
#  0.03632178371173037,
#  0.034401802597067634,
#  0.034611860329144845,
#  0.034619921988403204]

# %%
## Decision Tree ## 
Cs=[0.1,1,10,100,1000]
#epsilon=[]


CLF_A=[SVR(C=Cs[i], epsilon=0.1) for i in range(len(Cs))]
MSE=[]
r2Score=[]
for clf in CLF_A:
    clf_name = clf.__class__.__name__
    
    # Train #
    clf.fit(X_train, y_train)

    # Predict #
    results[clf_name] = clf.predict(X_test)
    MSE.append(mean_squared_error(y_test,results[clf_name]))
    r2Score.append(r2_score(y_test,results[clf_name]))
    plt=plot_square(y_test, results[clf_name],0,1,Title=clf_name)    
    
#    plt.figure()
#    plt.scatter(y_test, results[clf_name], s=20, edgecolor="black",c="darkorange", label="data")
#    plt.xlabel("Observed CR")
#    plt.ylabel("Predicted CR")
#    plt.title(clf_name+" Regression")
#    plt.legend()

plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# No handles with labels found to put in legend.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# No handles with labels found to put in legend.
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/utils/validation.py:73: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# ...

# %%
r2Score
# Out:
# [-0.1663717422776705,
#  -0.03734433738132181,
#  0.10631914901826434,
#  0.3980045184600174,
#  0.438118886507305]

# %%
y_test.sum()
y_test.shape
# Out:
# (320, 1)

# %% [raw]
# # TODO: Initialize the three models
#
# clf_B = SVR(C=1.0, epsilon=0.2)
#
#
# clf_C = AdaBoostRegressor(random_state=0, n_estimators=20)
#
# samples = len(X_train)
#
# # Collect results on the learners
# results = {}
# for clf in [clf_A, clf_B, clf_C]:
#     clf_name = clf.__class__.__name__
#
#     # Train #
#     clf.fit(X_train, y_train)
#
#     # Predict #
#     results[clf_name] = clf.predict(X_test)
#
#
#     plt=plot_square(y_test, results[clf_name],0,1,Title=clf_name)
#
# #    plt.figure()
# #    plt.scatter(y_test, results[clf_name], s=20, edgecolor="black",c="darkorange", label="data")
# #    plt.xlabel("Observed CR")
# #    plt.ylabel("Predicted CR")
# #    plt.title(clf_name+" Regression")
# #    plt.legend()
#     plt.show()

# %% [markdown]
# ## Reduce number of features, better keyword Handling ##

# %% [markdown]
# ## More data processing ##

# %%
Keyword_Performance[:10]
Keyword_Performance.sort_values(by=['Revenue/Cost','Clicks'],ascending=False)
# Out:
#                                                     Clicks  $ Ad Cost      CR  \
# building structural engineer                           1.0       7.78    0.00
# structural engineer inspection near me                 4.0      44.18    1.00
# structural analysis services                           2.0      17.03    0.00
# structural engineer home inspection                    8.0      94.94    0.00
# structural engineer costs                              5.0      38.06    0.00
# structural engineering consulting firms                1.0      12.28    0.00
# residential construction engineer                      7.0      51.89    0.00
# steel structural engineer                              4.0      25.36    0.00
# structural firm                                        4.0      39.19    0.00
# residential structural inspection                      8.0      93.60    2.00
# best structural engineer                               7.0      62.01    0.33
# ...

# %% [markdown]
# # NLTK USE: Data Cleaning and text preprocessing #

# %%
class NLTKPreprocesor(BaseEstimator,TransformerMixin):
    # This class is taking care of NLP preprocessing steps, 
    # Breaking sentence to its words, lowering the case, removing stop words, and lemmatizing ## 
    def __init__(self,stopwords = None,punct = None,lower = True,strip=True):
        self.lower = lower
        self.strip = strip
        self.stopwords = stopwords or set(sw.words('english'))
        self.punct = punct or set(string.punctuation)
        self.lemmatizer = WordNetLemmatizer()
#        self.contractions = load(open('contractions.pickle','rb'))


    def transform(self,X):
        # Transform the list of comments into list of list of words #
        return [list(self.tokenize(doc)) for doc in X]

    def tokenize(self,document):
        # This function, recieves a commesnt and turn it into list of words, while removing emoticons, 
        # stripping the space, and lower the case #
        for sent in sent_tokenize(document):
            for token,tag in pos_tag(wordpunct_tokenize(sent)):
                token = token.lower() if self.lower else token
                token = token.strip() if self.strip else token
                token = token.strip('_') if self.strip else token
                token = token.strip('*') if self.strip else token
                token = token.strip('#') if self.strip else token


#                if token in self.stopwords:
#                    continue

                if all(char in self.punct for char in token):
                    continue

                if len(token) <= 0:
                    continue
                
                lemma = self.lemmatize(token,tag)
                yield lemma

    def lemmatize(self,token,tag):
        tag ={
            'N' : wn.NOUN,
            'V' : wn.VERB,
            'R' : wn.ADV,
            'J' : wn.ADJ
        }.get(tag[0],wn.NOUN)
        return self.lemmatizer.lemmatize(token,tag)


def prepare_data(X,X_t):
    preProcess = Pipeline([
        ('NLTKpreprocess', NLTKPreprocesor()),
        ('vectorizer', TfidfVectorizer(
            max_df=0.90,
            max_features=5000,
            encoding='latin1',
            tokenizer=lambda x: x,
            preprocessor=None, lowercase=False))
    ])
    x_train = np.asanyarray(preProcess.fit_transform(X.values).todense())
    x_test = np.asanyarray(preProcess.transform(X_t.values).todense())

    return x_train,x_test,preProcess


def trim(s):
    """Trim string to fit on terminal (assuming 80-column display)"""
    return s if len(s) <= 80 else s[:77] + "..."

# %%
if __name__ == '__main__':
    ## Calling the class, and applying on dataset ## 
    clf = NLTKPreprocesor()
    procData = clf.transform(final_df.loc[:, 'Keyword']) ## preprocessing the comments ##

# %%
procData
# Out:
# [['structural', 'engineer'],
#  ['structural', 'engineer', 'near', 'me'],
#  ['structural', 'engineer'],
#  ['structural', 'engineer'],
#  ['foundation', 'structural', 'engineer'],
#  ['windstorm', 'inspection'],
#  ['foundation', 'crack'],
#  ['structural', 'engineer', 'near', 'me'],
#  ['structural', 'inspection'],
#  ['foundation', 'engineering'],
#  ['foundation', 'structural', 'engineer'],
#  ['structural', 'engineer'],
#  ['structural', 'inspection'],
#  ['structural', 'engineer', 'inspection'],
#  ['structural', 'engineer'],
#  ['structural', 'engineer', 'cost'],
#  ['residential', 'foundation', 'engineer'],
#  ['structural', 'engineer'],
#  ['structural', 'engineering', 'firm'],
#  ['structural', 'engineer', 'near', 'me'],
#  ['structural', 'engineer'],
#  ['foundation', 'engineering'],
#  ['foundation', 'engineering'],
#  ['foundation', 'crack'],
#  ['windstorm', 'inspection'],
#  ['structural', 'engineer'],
#  ['structural', 'engineer'],
#  ['structural', 'engineer'],
# ...

# %% [markdown]
# ## Tokenizing, padding each keyword into similar size arrow ##

# %%
## Tokenizer ## 
#Keywords=[]
text=[]
for x in procData:
    x=' '.join(x)
    text.append(x)
text=np.asarray(text)

# %%
max_features = 70 ## Max features is depending on size set ## 
tokenizer = Tokenizer(num_words=max_features)
tokenizer.fit_on_texts(list(np.asarray(text)))
list_tokenized_train = tokenizer.texts_to_sequences(text)

# %%
tz=tokenizer.word_counts
sorted_tokens = sorted(tz.items(), key=operator.itemgetter(1))

# %%
sorted_tokens
tL=len(sorted_tokens)
print("Popular words in Toxic Comments")
for i in range(tL-1,tL-10,-1):
    print(sorted_tokens[i])
# Out:
# Popular words in Toxic Comments
# ('structural', 2235)
# ('engineer', 2048)
# ('inspection', 709)
# ('foundation', 466)
# ('engineering', 420)
# ('me', 354)
# ('near', 354)
# ('windstorm', 235)
# ('home', 215)

# %%
N_Ads=len(list_tokenized_train)
N_features=tL+15 ## 14 area codes, 1 CPC 
Key_Matrix=np.zeros((N_Ads,N_features))
for i in range(N_Ads):
    for j in list_tokenized_train[i]:
        Key_Matrix[i,j-1]=1

# %% [markdown]
# ## Creating Input, Out Features ##

# %%
Hot_Encoded=['AreaCode']
Target=['CR']
Extra_Predictant=['CPC']
dummy=final_df[Hot_Encoded]
features_final = pd.get_dummies(dummy)
Key_Matrix[:,tL:-1]=features_final
Key_Matrix[:,-1]=list(final_df['CPC'])
#features_final[Extra_Predictant]=final_df[Extra_Predictant]
target=final_df[Target]

# %%
Key_Matrix[:,-2]

# %%
# Import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.model_selection import train_test_split

# Split the 'features' and 'income' data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(Key_Matrix, 
                                                    target, 
                                                    test_size = 0.1, 
                                                    random_state = 1)

# Show the results of the split
print("Training set has {} samples.".format(X_train.shape[0]))
print("Testing set has {} samples.".format(X_test.shape[0]))
# Out:
# Training set has 2880 samples.
# Testing set has 320 samples.

# %%
## Decision Tree ## 
Max_Depths=[1,10,20,30,40,50,100]
CLF_A=[DecisionTreeRegressor(max_depth=Max_Depths[i],min_samples_leaf=1) for i in range(len(Max_Depths))]
MSE=[]
r2Score=[]
for clf in CLF_A:
    clf_name = clf.__class__.__name__
    
    # Train #
    clf.fit(X_train, y_train)

    # Predict #
    results[clf_name] = clf.predict(X_test)
    MSE.append(mean_squared_error(y_test,results[clf_name]))
    r2Score.append(r2_score(y_test,results[clf_name]))
    
    plt=plot_square(y_test, results[clf_name],0,1,Title=clf_name)    
    
#    plt.figure()
#    plt.scatter(y_test, results[clf_name], s=20, edgecolor="black",c="darkorange", label="data")
#    plt.xlabel("Observed CR")
#    plt.ylabel("Predicted CR")
#    plt.title(clf_name+" Regression")
#    plt.legend()
    plt.show()
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.

# %%
r2Score
# Out:
# [0.035194472446678504,
#  0.5710910910048181,
#  0.8097434627078897,
#  0.7867646839941864,
#  0.800075075715902,
#  0.8421505710377305,
#  0.8543494907353825]

# %% [markdown]
# # Word2Vec Google TL #

# %%
from gensim.models import Word2Vec
 
sentences = [["bad","robots"],["good","human"],['yes', 'this', 'is', 'the', 'word2vec', 'model']]
 
# size option needs to be set to 300 to be the same as Google's pre-trained model
 
word2vec_model = Word2Vec(size = 300, window=5,
min_count = 1, workers = 2)
 
word2vec_model.build_vocab(sentences)
 
# assign the vectors to the vocabs that are in Google's pre-trained model and your sentences defined above.
 
# lockf needs to be set to 1.0 to allow continued training.
 
word2vec_model.intersect_word2vec_format('PreTrained/GoogleNews-vectors-negative300.bin', lockf=1.0, binary=True)
 
# continue training with you own data
# Out:
# (4, 50)

# %%
word2vec_model.train(sentences, total_examples=3, epochs = 5)
# Out:
# 'structural engineer near me'
